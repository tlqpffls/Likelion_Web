# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import time
from wordcloud import WordCloud
import numpy as np
from PIL import image

# %%
url = 'https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=171725&target=after'

# %%
# url = 'https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=171725&target=after'
basic_url = "https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=171725&target=after&page="
# 2page 
# 3page

# %%
page = urlopen(basic_url + '1')
soup = BeautifulSoup(page, 'lxml')
comment_all = soup.find_all('td', class_='title')
comment_all
# Out:
# [<td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=171725">스파이더맨: 뉴 유니버스</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:60%">별점 - 총 10점 중</span></span><em>6</em>
#  </div>
#  <br/>곤니찌와에서 ㅡ ㅡ ... 재밌다가 식었음 ㅠ
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('chac****', 'FSphKGKmOdiXEgqOq/PJEl4HzLpUcchGqWm/SFdDL64=', '곤니찌와에서 ㅡ ㅡ ... 재밌다가 식었음 ㅠ', '17551922', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>, <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=171725">스파이더맨: 뉴 유니버스</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>이게 예술이 아니면 뭔가요?
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('froz****', 'CodTfv19SDPoY3jspatXPAP7xX4bD46wIeCcaDz3mEI=', '이게 예술이 아니면 뭔가요?', '17550850', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>, <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=171725">스파이더맨: 뉴 유니버스</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>와 ㄹㅇ 내 인생 영화에 들어갈정도로 재밌음. 특유의 BOOM이라던가 만화같은 연출이랑 팝송같은 음악이 너무 좋았음
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('mua5****', 'sgMo3fgvtsmPM9IkxK/rZ8XWPoGEiQ6BYOmwv3thNGc=', '와 ㄹㅇ 내 인생 영화에 들어갈정도로 재밌음. 특유의 BOOM이라던가 만화같은 연출이랑 팝송같은 음악이 너무 좋았음', '17533816', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>, <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=171725">스파이더맨: 뉴 유니버스</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>명대사:헤이
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('gaon****', 'Oe4l31FacZXC5YSCYODuefC0AIXJ7uSf88BkTxsiZOI=', '명대사:헤이', '17532776', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>, <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=171725">스파이더맨: 뉴 유니버스</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>진짜 고퀄리티다....
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('tvtp****', 'zGqA5NhCG1r5rEC7rOT2yzUbvI48cBW+sgmCO3J1CWk=', '진짜 고퀄리티다.... ', '17531921', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>, <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=171725">스파이더맨: 뉴 유니버스</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:90%">별점 - 총 10점 중</span></span><em>9</em>
#  </div>
#  <br/>스파이더맨 판권을 소니가 가져야 하는 이유
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('thsw****', 'i9MRCl4OC2Vlsmaqqb1Nre5ULrI0XgYj3lH6OMvdp60=', '스파이더맨 판권을 소니가 가져야 하는 이유', '17530664', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>, <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=171725">스파이더맨: 뉴 유니버스</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>갠적으로 영화 2번이상 보고싶은거 없었는데 생겼다. 힘든요즘 힘내게 해준영화 왜 이제봤지?
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('gksl****', 'SnV9SUg6UTL8F1TxTH+Ac+oAg84Y+fyJIz5mV7vD/f4=', '갠적으로 영화 2번이상 보고싶은거 없었는데 생겼다. 힘든요즘 힘내게 해준영화 왜 이제봤지?', '17528002', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>, <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=171725">스파이더맨: 뉴 유니버스</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:90%">별점 - 총 10점 중</span></span><em>9</em>
#  </div>
#  <br/>영화도 재밌는데 연출이 일단 개신선하고 무엇보다 ost가 진짜 죽인다 ㅋㅋㅋㅋ
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('qwe2****', '/YDv1jejxqkwrJs2nkGjXs3qp8IM+Qn3zcUudPv7zII=', '영화도 재밌는데 연출이 일단 개신선하고 무엇보다 ost가 진짜 죽인다 ㅋㅋㅋㅋ', '17527391', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>, <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=171725">스파이더맨: 뉴 유니버스</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>영상미 색감 액션 정말 삼박자를 다갖춘 영화에요ㅜㅜㅜ 다채로운 색의 조합이 눈을 즐겁게 만들고 화려한액션은 정말 말할것도 없네요.... 극장에서 못본게 아쉽네요 정말 재밌게 봤습니다 !!
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('k194****', 'luE1w5aYwdyF8mEuKtW37awifyKrysgrx52xgXs7Su8=', '영상미 색감 액션 정말 삼박자를 다갖춘 영화에요ㅜㅜㅜ 다채로운 색의 조합이 눈을 즐겁게 만들고 화려한액션은 정말 말할것도 없네요.... 극장에서 못본게 아쉽네요 정말 재밌게 봤습니다 !!', '17526928', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>, <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=171725">스파이더맨: 뉴 유니버스</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
#  </div>
#  <br/>이게 진짜 현대예술이지
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('aekq****', 'c2BJHOEx49YCH9Zkt4JYfUM3e7KUQsvwyU6tTTZaJjo=', '이게 진짜 현대예술이지', '17516944', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>]

# %%
comments = []

for i in comment_all :
    one_com = i.contents[6].strip()
#     one_com = list(i.children)[6].strip()
#     one_com = i.find('a', class_='report').get('onclick').split(',')[2].strip(()
    
    comments.append(one_com)

# %%
comments
# Out:
# [" '곤니찌와에서 ㅡ ㅡ ... 재밌다가 식었음 ㅠ",
#  " '이게 예술이 아니면 뭔가요?",
#  " '와 ㄹㅇ 내 인생 영화에 들어갈정도로 재밌음. 특유의 BOOM이라던가 만화같은 연출이랑 팝송같은 음악이 너무 좋았음",
#  " '명대사:헤이",
#  " '진짜 고퀄리티다.... ",
#  " '스파이더맨 판권을 소니가 가져야 하는 이유",
#  " '갠적으로 영화 2번이상 보고싶은거 없었는데 생겼다. 힘든요즘 힘내게 해준영화 왜 이제봤지?",
#  " '영화도 재밌는데 연출이 일단 개신선하고 무엇보다 ost가 진짜 죽인다 ㅋㅋㅋㅋ",
#  " '영상미 색감 액션 정말 삼박자를 다갖춘 영화에요ㅜㅜㅜ 다채로운 색의 조합이 눈을 즐겁게 만들고 화려한액션은 정말 말할것도 없네요.... 극장에서 못본게 아쉽네요 정말 재밌게 봤습니다 !!",
#  " '이게 진짜 현대예술이지"]

# %%
basic_url = "https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=171725&target=after&page="
comments = []

for i in range(1, 8) :
    page = urlopen(basic_url + str(i))
    soup = BeautifulSoup(page, 'lxml')
    comment_all = soup.find_all('td', class_='title')
    
    for j in comment_all :
        one_com = j.contents[6].strip()
        comments.append(one_com)
    
    time.sleep(3)
    
    
# # 강사님 코드 1
# comments_allpage = []
# cnt = 0
# for i in range(1,8):
#     url = basic_url + str(i)
#     page = urlopen(url)
#     soup = BeautifulSoup(page, 'html.parser')
#     comment_all = soup.find_all('td', class_='title')
#     #comments = []
#     for one in comment_all:
#         one_com = list(one.children)[6].strip()
#         #comments.append(one_com)
#         comments_allpage.append(comments)
#     time.sleep(3)
# print(len(comments_allpage))
# # print(len(comments_allpage))


# # 강사님 코드 2
# import time
# comments = []
# cnt = 0
# for i in range(1, 8):
#     print(">>> %d 페이지를 출력합니다.\n"%i)
#     url = basic_url + str(i)
#     page = urlopen(url)
#     soup = BeautifulSoup(page, "html.parser")
#     comment_all = soup.find_all('td', class_='title') 
#     for comment in comment_all:
#         temp= list(comment.children) 
#         if len(temp) < 5:
#             cnt= cnt + 1
#             print("len<5 case :",cnt) 
#             continue
#         else: 
#             try:
#                 cnt= cnt + 1
#                 result = temp[6].strip() 
#                 comments.append(result)
#             except:
#                 cnt = cnt + 1
#                 print("len>=5 case ",cnt)
#                 print(temp)
#     print(comments[-10:],"\n")
#     time.sleep(3)
# print(">>> 총 리뷰 %d개를 출력하였습니다."%len(comments))

# %%
# comments

# %%
dict_doc = {'text' : comments}
doc = pd.DataFrame(dict_doc)
doc.to_csv('스파이더맨리뷰_0617.csv', index=False)

# %%
from wordcloud import WordCloud
import numpy as np
# from PIL import image

# %%
with open('스파이더맨리뷰_0617.csv', encoding='utf-8') as f :
    text = f.read()

# %%
from matplotlib import rc
rc('font', family='NanumGothic')

# %%
wcloud = WordCloud('./data/D2Coding.ttf',
                   max_words=1000,
                   relative_scaling = 0.2).generate(text)
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
plt.imshow(wcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
# C:\Users\Su\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1241: UserWarning: findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
